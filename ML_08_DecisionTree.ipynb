# %%
import pandas as aju
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sn

# %%
df = aju.read_csv('D:\\MACHINE LEARNING\\DATASETS\\ML_08_DecisionTree_Salaries.csv')
df.head()
# Out:
#   company                  job     degree  salary_more_then_100k
# 0  google      sales executive  bachelors                      0
# 1  google      sales executive    masters                      0
# 2  google     business manager  bachelors                      1
# 3  google     business manager    masters                      1
# 4  google  computer programmer  bachelors                      0

# %%
le = LabelEncoder()
df['company'] = le.fit_transform(df['company'])
# Out:
#     company                  job     degree  salary_more_then_100k
# 0         2      sales executive  bachelors                      0
# 1         2      sales executive    masters                      0
# 2         2     business manager  bachelors                      1
# 3         2     business manager    masters                      1
# 4         2  computer programmer  bachelors                      0
# 5         2  computer programmer    masters                      1
# 6         0      sales executive    masters                      0
# 7         0  computer programmer  bachelors                      0
# 8         0     business manager  bachelors                      0
# 9         0     business manager    masters                      1
# 10        1      sales executive  bachelors                      1
# 11        1      sales executive    masters                      1
# 12        1     business manager  bachelors                      1
# 13        1     business manager    masters                      1
# 14        1  computer programmer  bachelors                      1
# 15        1  computer programmer    masters                      1

# %%
df['job'] = le.fit_transform(df['job'])
df
# Out:
#     company  job     degree  salary_more_then_100k
# 0         2    2  bachelors                      0
# 1         2    2    masters                      0
# 2         2    0  bachelors                      1
# 3         2    0    masters                      1
# 4         2    1  bachelors                      0
# 5         2    1    masters                      1
# 6         0    2    masters                      0
# 7         0    1  bachelors                      0
# 8         0    0  bachelors                      0
# 9         0    0    masters                      1
# 10        1    2  bachelors                      1
# 11        1    2    masters                      1
# 12        1    0  bachelors                      1
# 13        1    0    masters                      1
# 14        1    1  bachelors                      1
# 15        1    1    masters                      1

# %%
df['degree'] = le.fit_transform(df['degree'])
df
# Out:
#     company  job  degree  salary_more_then_100k
# 0         2    2       0                      0
# 1         2    2       1                      0
# 2         2    0       0                      1
# 3         2    0       1                      1
# 4         2    1       0                      0
# 5         2    1       1                      1
# 6         0    2       1                      0
# 7         0    1       0                      0
# 8         0    0       0                      0
# 9         0    0       1                      1
# 10        1    2       0                      1
# 11        1    2       1                      1
# 12        1    0       0                      1
# 13        1    0       1                      1
# 14        1    1       0                      1
# 15        1    1       1                      1

# %%
x = df.drop('salary_more_then_100k',axis = 'columns')
y = df['salary_more_then_100k']

# %%
model = tree.DecisionTreeClassifier()
model.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x,y)
# Out:
# 1.0

# %%
model.predict([[2,2,1]])
# Out:
# D:\python_anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
model.predict([[2,1,0]])
# Out:
# D:\python_anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
model.predict([[1,1,0]])
# Out:
# D:\python_anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
file = aju.read_csv('D:\\MACHINE LEARNING\\DATASETS\\ML_08_DecisionTree_Titanic.csv')
file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
file['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
file.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
file_df = file[['Survived','Pclass','Age','Fare','Sex']]
file_df
# Out:
#      Survived  Pclass   Age     Fare     Sex
# 0           0       3  22.0   7.2500    male
# 1           1       1  38.0  71.2833  female
# 2           1       3  26.0   7.9250  female
# 3           1       1  35.0  53.1000  female
# 4           0       3  35.0   8.0500    male
# ..        ...     ...   ...      ...     ...
# 886         0       2  27.0  13.0000    male
# 887         1       1  19.0  30.0000  female
# 888         0       3   NaN  23.4500  female
# 889         1       1  26.0  30.0000    male
# 890         0       3  32.0   7.7500    male
#
# [891 rows x 5 columns]

# %%
file_df['Age'].isnull().sum()
# Out:
# 177

# %%
mean_age = file_df['Age'].mean()

# %%
file_df['Age'] = file_df['Age'].fillna(mean_age)
# Out:
# C:\Users\AJU\AppData\Local\Temp\ipykernel_12732\4244535445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_df['Age'] = file_df['Age'].fillna(mean_age)

# %%
file_df
# Out:
#      Survived  Pclass        Age     Fare     Sex
# 0           0       3  22.000000   7.2500    male
# 1           1       1  38.000000  71.2833  female
# 2           1       3  26.000000   7.9250  female
# 3           1       1  35.000000  53.1000  female
# 4           0       3  35.000000   8.0500    male
# ..        ...     ...        ...      ...     ...
# 886         0       2  27.000000  13.0000    male
# 887         1       1  19.000000  30.0000  female
# 888         0       3  29.699118  23.4500  female
# 889         1       1  26.000000  30.0000    male
# 890         0       3  32.000000   7.7500    male
#
# [891 rows x 5 columns]

# %%
file_df['Age'].isnull().sum()
# Out:
# 0

# %%
file_df.Sex = file_df.Sex.map({'male':1,'female':2})
file_df
# Out:
# C:\Users\AJU\AppData\Local\Temp\ipykernel_12732\2852807569.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_df.Sex = file_df.Sex.map({'male':1,'female':2})
#      Survived  Pclass        Age     Fare  Sex
# 0           0       3  22.000000   7.2500    1
# 1           1       1  38.000000  71.2833    2
# 2           1       3  26.000000   7.9250    2
# 3           1       1  35.000000  53.1000    2
# 4           0       3  35.000000   8.0500    1
# ..        ...     ...        ...      ...  ...
# 886         0       2  27.000000  13.0000    1
# 887         1       1  19.000000  30.0000    2
# 888         0       3  29.699118  23.4500    2
# 889         1       1  26.000000  30.0000    1
# 890         0       3  32.000000   7.7500    1
#
# [891 rows x 5 columns]

# %%
x = file_df.drop('Survived',axis = 'columns')
y = file_df.Survived

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 33)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 0.8212290502793296

# %%
y_pred = model.predict(x_test)

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[97, 10],
#        [22, 50]], dtype=int64)

# %%
sn.heatmap(cm,annot = True)
# Out:
# <Axes: >
